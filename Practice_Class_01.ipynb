# %% [markdown]
# <a href="https://colab.research.google.com/github/SohelPharmacy/Skill_Morph/blob/main/Practice_Class_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Coding Programm**

# %% [markdown]
# ## **Name**
